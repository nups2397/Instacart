# %% [markdown]
# # Table of Contents
#
# ## Importing Libraries
#
# ## Importing Dataframes
#
# ## Reading Tasks
# ### - If-Statements with User-Defined Functions
# ### - If-Statements with the loc() Function
# ### - If-Statements with For-Loops
#
# ## Task Questions
# ### - Step 2: New Column for "Busiest Days"
# ### - Step 3: Check Values of Busiest Days Column
# ### - Step 4: Creating Busiest Period of the Day Column
# ### - Step 5: Print Frequency of New Column
#
# ## Export as a Pickle File

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as ny
import os

# %% [markdown]
# # Importing Dataframes

# %%
#Definining path
path= r'C:\Users\princess\Documents\09-2023 Instacart Basket Analysis'

# %%
# Import ords_prods_merged
df_ords_prods_merged =  pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data','orders_products_merged.pkl'))

# %% [markdown]
# # Reading Tasks

# %%
# Create subset of first 1M rows
df = df_ords_prods_merged[:1000000]

# %%
# Check shape of new subset
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# ## If-Statements with User-Defined Functions

# %% [markdown]
# ### Creating Flag for Price Labels

# %%
#Defining price label conditions 

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\princess\AppData\Local\Temp\ipykernel_18100\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## If-Statements with the loc() Function

# %%
df.loc[(df['prices']>15),'price_range_loc']='High range'
# Out:
# C:\Users\princess\AppData\Local\Temp\ipykernel_18100\1560760473.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[(df['prices']>15),'price_range_loc']='High range'

# %%
df.loc[(df['prices']>5)&(df['prices']<=15),'price_range_loc']='Mid range'

# %%
df.loc[df['prices']<=5,'price_range_loc']='Low range'

# %%
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid range    756450
# Low range    243550
# Name: count, dtype: int64

# %% [markdown]
# #### Creating price-range

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices']>15),'price_range']='High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices']>5)&(df_ords_prods_merged['prices']<=15),'price_range']='Mid-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices']<=5),'price_range']='Low-range product'

# %%
df_ords_prods_merged['price_range'].value_counts()
# Out:
# price_range
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    NaN         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices        price_range
# ...

# %% [markdown]
# ## If-Statements with For-Loops

# %%
# Create new column in dataframe
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# create a for-loop that append to the 'result' list the busiest of the days based on values in the 'orders_day_of_week' column

result = []

for value in df_ords_prods_merged['orders_day_of_week']:
  if value == 0:
    result.append('Busiest day')
  elif value == 4:
    result.append('Least busy')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Add result to dataframe
df_ords_prods_merged['busiest_day'] = result

# %%
# Check value counts
df_ords_prods_merged['busiest_day'].value_counts()
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Task Questions

# %% [markdown]
# # Step 2: New Column for "Busiest Days"

# %% [markdown]
# #### Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Create new if-statement for-loop for new requirements
result_v2 = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_v2.append("Busiest days")
  elif value == 4 or value == 3:
    result_v2.append("Least busy days")
  else:
    result_v2.append("Regularly busy")

# %%
# Add result to dataframe in new column
df_ords_prods_merged['busiest_days'] = result_v2

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    NaN         196                  1          0   both
# 1                   15.0         196                  1          1   both
# 2                   21.0         196                  1          1   both
# 3                   29.0         196                  1          1   both
# 4                   28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices        price_range  \
# ...

# %% [markdown]
# # Step 3: Check Values of Busiest Days Column

# %% [markdown]
# #### Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
#Check value counts of new column busiest_days

df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: count, dtype: int64

# %% [markdown]
# # Step 4: Creating Busiest Period of the Day Column

# %% [markdown]
# #### When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# Check frequency values of order_hour_of_day

df_ords_prods_merged['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# #### Since the client wants the hours grouped into three different periods of time, the 24 hours of the day can be grouped as follows: Most orders = 10, 11, 14, 15, 13, 12, 16, 9; Average orders = 17, 8, 18, 19, 20, 7, 21, 22; Fewest orders = 23, 6, 0, 1, 5, 2, 4, 3

# %%
# Create a for-loop if statement for the busiest periods of the day 

hour_of_day = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    hour_of_day.append("Fewest orders")
  else:
    hour_of_day.append("Average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
df_ords_prods_merged['busiest_period_of_day'] = hour_of_day

# %%
# Check headings
df_ords_prods_merged[['order_hour_of_day', 'busiest_period_of_day']].head(16)
# Out:
#     order_hour_of_day busiest_period_of_day
# 0                   8        Average orders
# 1                   7        Average orders
# 2                  12           Most orders
# 3                   7        Average orders
# 4                  15           Most orders
# 5                   7        Average orders
# 6                   9           Most orders
# 7                  14           Most orders
# 8                  16           Most orders
# 9                   8        Average orders
# 10                  9           Most orders
# 11                 16           Most orders
# 12                 11           Most orders
# 13                  9           Most orders
# 14                 10           Most orders
# 15                 14           Most orders

# %% [markdown]
# # Step 5: Print Frequency of New Column

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# # Export as a Pickle File

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged_updated.pkl'))
